# %%
"""
Q.5 Can we create an instance of an abstract class? Explain your answer.

Ans.yes I create a abstract class
"""

# %%
from abc import ABC ,abstractmethod

# %%
class abstract(ABC):
    @abstractmethod
    def my_method (self):
        pass
class pwskills(abstract):
    def my_method(self):
        print("MY frist program in abstraction :")

# %%
# create object
my_object=pwskills()

# %%
my_object.my_method()
# Out:
# MY frist program in abstraction :
