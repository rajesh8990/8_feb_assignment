# %%
"""
Q.3 What is abc module in python? Why is it used?

Ans. The 'abc' module in Python, short for 'Abstract Base Classes,' allows you to set up 
    a blueprint or a template for classes without providing a complete implementation.
    Blueprints in programming, or design templates, are used for several reasons: such as 
    Consistency,Efficiency,Standardization
