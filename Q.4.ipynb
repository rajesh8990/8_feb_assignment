# %%
"""
Q.4 How can we achieve data abstraction?

Ans.Data abstraction in programming is like having a secret agent. You only get to see what they
    do on the surface without knowing all the complicated stuff they handle behind the scenes.
